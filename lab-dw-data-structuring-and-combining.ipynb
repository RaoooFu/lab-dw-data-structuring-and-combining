# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# Your code goes here
import pandas as pd

url_1='https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'
url_2='https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv'
url_3='https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv'
df_1=pd.read_csv(url_1)
df_2=pd.read_csv(url_2)
df_3=pd.read_csv(url_3)
df_1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df_1=df_1.rename(columns={'ST':'State','GENDER':'Gender'})
df_1
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df_2=df_2.rename(columns={'ST':'State','GENDER':'Gender'})
df_2
# Out:
#     Customer       State Gender Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df_3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
print("Rows in df_1:", df_1.shape[0])
print("Rows in df_2:", df_2.shape[0])
print("Rows in df_3:", df_3.shape[0])
expected_total = df_1.shape[0] + df_2.shape[0] + df_3.shape[0]
print("Expected Total Rows:", expected_total)
# Out:
# Rows in df_1: 4008
# Rows in df_2: 996
# Rows in df_3: 7070
# Expected Total Rows: 12074

# %%
df=pd.concat([df_1,df_2,df_3],ignore_index=True)
#ignore_index resets the index by forgetting the old index
df
# Out:
#       Customer       State Gender             Education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %%
df=df.apply(lambda x:x.str.strip().str.lower() if x.dtype == "object" else x)
df
# Out:
#       Customer       State Gender             Education  \
# 0      rb50392  washington    NaN                master
# 1      qz44356     arizona      f              bachelor
# 2      ai49188      nevada      f              bachelor
# 3      ww63253  california      m              bachelor
# 4      ga49547  washington      m  high school or below
# ...        ...         ...    ...                   ...
# 12069  la72316  california      m              bachelor
# 12070  pk87824  california      f               college
# 12071  td14365  california      m              bachelor
# 12072  up19263  california      m               college
# 12073  y167826  california      m               college
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %%
df['Education'].value_counts()
# Out:
# Education
# bachelor                2719
# college                 2682
# high school or below    2616
# master                   752
# doctor                   344
# bachelors                 24
# Name: count, dtype: int64

# %%
df['Education']=df['Education'].replace({'bachelors':'bachelor'})
df['Education'].value_counts()
# Out:
# Education
# bachelor                2743
# college                 2682
# high school or below    2616
# master                   752
# doctor                   344
# Name: count, dtype: int64

# %%
df['State'].value_counts()
# Out:
# State
# california    2755
# oregon        2298
# arizona       1488
# nevada         757
# washington     668
# cali           120
# wa              30
# az              25
# Name: count, dtype: int64

# %%
df['State']=df['State'].replace({'cali':'california','az':'arizona','wa':'washington'})
df['State'].value_counts()
# Out:
# State
# california    2875
# oregon        2298
# arizona       1513
# nevada         757
# washington     698
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# f         4033
# m         3907
# male        39
# female      28
# femal       17
# Name: count, dtype: int64

# %%
df['Gender']=df['Gender'].replace({'f':'female','femal':'female','m':'male'})
df['Gender'].value_counts()
# Out:
# Gender
# female    4078
# male      3946
# Name: count, dtype: int64

# %%
df['Customer Lifetime Value']=df['Customer Lifetime Value'].replace({'%':''},regex=True)
df['Customer Lifetime Value']=pd.to_numeric(df['Customer Lifetime Value'],errors='coerce')
df['Customer Lifetime Value'] = df['Customer Lifetime Value'].fillna(0).astype(int)
df['Customer Lifetime Value']
# Out:
# 0              0
# 1         697953
# 2        1288743
# 3         764586
# 4         536307
#           ...
# 12069          0
# 12070          0
# 12071          0
# 12072          0
# 12073          0
# Name: Customer Lifetime Value, Length: 12074, dtype: int64

# %%
df.fillna('na')
# Out:
#       Customer       State  Gender             Education  \
# 0      rb50392  washington      na                master
# 1      qz44356     arizona  female              bachelor
# 2      ai49188      nevada  female              bachelor
# 3      ww63253  california    male              bachelor
# 4      ga49547  washington    male  high school or below
# ...        ...         ...     ...                   ...
# 12069  la72316  california    male              bachelor
# 12070  pk87824  california  female               college
# 12071  td14365  california    male              bachelor
# 12072  up19263  california    male               college
# 12073  y167826  california    male               college
#
#        Customer Lifetime Value   Income Monthly Premium Auto  \
# 0                            0      0.0               1000.0
# 1                       697953      0.0                 94.0
# 2                      1288743  48767.0                108.0
# ...

# %%
df['Policy Type'].value_counts()
# Out:
# Policy Type
# personal auto     6792
# corporate auto    1965
# special auto       380
# Name: count, dtype: int64

# %%
df['Vehicle Class'].value_counts()
# Out:
# Vehicle Class
# four-door car    4641
# two-door car     1896
# suv              1774
# sports car        483
# luxury suv        182
# luxury car        161
# Name: count, dtype: int64

# %%
df['Total Claim Amount']=pd.to_numeric(df['Total Claim Amount'],errors='coerce')
df['Total Claim Amount']=df['Total Claim Amount'].fillna(0).astype(int)
df['Total Claim Amount']
# Out:
# 0           2
# 1        1131
# 2         566
# 3         529
# 4          17
#          ...
# 12069     198
# 12070     379
# 12071     790
# 12072     691
# 12073     369
# Name: Total Claim Amount, Length: 12074, dtype: int64

# %%
df
# Out:
#       Customer       State  Gender             Education  \
# 0      rb50392  washington     NaN                master
# 1      qz44356     arizona  female              bachelor
# 2      ai49188      nevada  female              bachelor
# 3      ww63253  california    male              bachelor
# 4      ga49547  washington    male  high school or below
# ...        ...         ...     ...                   ...
# 12069  la72316  california    male              bachelor
# 12070  pk87824  california  female               college
# 12071  td14365  california    male              bachelor
# 12072  up19263  california    male               college
# 12073  y167826  california    male               college
#
#        Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                            0      0.0                1000.0
# 1                       697953      0.0                  94.0
# 2                      1288743  48767.0                 108.0
# ...

# %%
df['Gender']=df['Gender'].rename({'female':'f','female':'femal','male':'m'})
df['Gender']
# Out:
# 0           NaN
# 1        female
# 2        female
# 3          male
# 4          male
#           ...
# 12069      male
# 12070    female
# 12071      male
# 12072      male
# 12073      male
# Name: Gender, Length: 12074, dtype: object

# %%
df.duplicated().sum()
# Out:
# 2936

# %%
df.nunique()
# Out:
# Customer                     9056
# State                           5
# Gender                          2
# Education                       5
# Customer Lifetime Value      1922
# Income                       5655
# Monthly Premium Auto          209
# Number of Open Complaints       6
# Policy Type                     3
# Vehicle Class                   6
# Total Claim Amount           1167
# ST                              6
# GENDER                          4
# dtype: int64

# %%
df_clean=df.drop_duplicates().reset_index(drop=True)
df_clean
# Out:
#      Customer       State  Gender             Education  \
# 0     rb50392  washington     NaN                master
# 1     qz44356     arizona  female              bachelor
# 2     ai49188      nevada  female              bachelor
# 3     ww63253  california    male              bachelor
# 4     ga49547  washington    male  high school or below
# ...       ...         ...     ...                   ...
# 9133  la72316  california    male              bachelor
# 9134  pk87824  california  female               college
# 9135  td14365  california    male              bachelor
# 9136  up19263  california    male               college
# 9137  y167826  california    male               college
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                           0      0.0                1000.0
# 1                      697953      0.0                  94.0
# 2                     1288743  48767.0                 108.0
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here
url_insurance='https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv'
df_insurance=pd.read_csv(url_insurance)
df_insurance
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
df_insurance=df_insurance.drop(columns='unnamed:_0')
df_insurance
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
df_insurance['state'].value_counts()
# Out:
# state
# California    4183
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: count, dtype: int64

# %%
df_insurance['coverage'].value_counts()
# Out:
# coverage
# Basic       6660
# Extended    3265
# Premium      985
# Name: count, dtype: int64

# %%
df_insurance['employmentstatus'].value_counts()
# Out:
# employmentstatus
# Employed         6789
# Unemployed       2787
# Medical Leave     504
# Disabled          499
# Retired           331
# Name: count, dtype: int64

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
pivot_table=df_insurance.pivot_table(
    index='sales_channel',
    values='total_claim_amount',
    aggfunc='sum').round(2)
pivot_table
# Out:
#                total_claim_amount
# sales_channel
# Agent                  1810226.82
# Branch                 1301204.00
# Call Center             926600.82
# Web                     706600.04

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
pivot_clv = df_insurance.pivot_table(
    values='customer_lifetime_value',
    index='gender',
    columns='education',
    aggfunc='mean'
).round(2)
pivot_clv
# Out:
# education  Bachelor  College   Doctor  High School or Below   Master
# gender
# F           7874.27  7748.82  7328.51               8675.22  8157.05
# M           7703.60  8052.46  7415.33               8149.69  8168.83

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
